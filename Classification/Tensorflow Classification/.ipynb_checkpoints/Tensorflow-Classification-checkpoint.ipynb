# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn 
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
import tensorflow_addons as tfa
import joblib
# Out:
# C:\Users\aswin\anaconda3\envs\myenv_tf\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# ### Data Collection

# %%
# read csv as df
df = pd.read_csv("Telco-Customer-Churn.csv")

# drop customer ID
df = df.drop(columns = ['customerID'], axis=1)

df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0     NaN         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %% [markdown]
# ### EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7039 non-null   object
#  3   Dependents        7039 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7040 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7037 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7042 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
# Change dtype of Monthly Charges from object to float
df['MonthlyCharges'] = df['MonthlyCharges'].astype(float)

# Change dtype of Monthly Charges from object to float
df['TotalCharges'] = df['TotalCharges'].replace(' ', np.nan)
df.dropna(subset=['TotalCharges'], inplace = True)
df['TotalCharges'] = df['TotalCharges'].astype(float)

# %%
# Label encode Target
le = LabelEncoder()
df['Churn'] = le.fit_transform(df['Churn'])

# %%
# get numerical and categorical column names
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns.to_list()
categorical_columns = df.select_dtypes(include=['object']).columns.to_list()

# %%
# Display histograms for numerical columns
for column in numerical_columns:
    sns.displot(df, x=column, height=2, aspect=2)

# %%
# Display barcharts for categorical columns
for column in categorical_columns:
    sns.catplot(df, x=column, kind="count", height=2, aspect=2)
    plt.xticks(rotation=45)

# %%
# visualize correlation matrix
correlation_matrix = df[numerical_columns].corr()

plt.figure(figsize=(10,4), dpi=500)
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
df.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             4
# Dependents          4
# tenure              0
# PhoneService        3
# MultipleLines       0
# InternetService     6
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         1
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      8
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# remove missing rows
df.dropna(subset=['Partner', 'Dependents', 'PhoneService', 
                  'OnlineSecurity', 'InternetService', 'StreamingTV', 'MonthlyCharges'], inplace = True)

# %%
df.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ### Data Split

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# feature selection
X = df[['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
       'MonthlyCharges', 'TotalCharges']]

# get numerical and categorical column names
numerical_columns = X.select_dtypes(include=['float64', 'int64']).columns.to_list()
categorical_columns = X.select_dtypes(include=['object']).columns.to_list()

# taget selection
y = df['Churn']

# %%
# train rest split
X_train, X_rest, y_train, y_rest = train_test_split(X, y, train_size=0.80, random_state=42, stratify=y)

# val test split
X_val, X_test, y_val, y_test = train_test_split(X_rest, y_rest, test_size=0.50, random_state=42, stratify=y_rest)

# print percentage of sets
print(f'Percentage of Train Set {X_train.shape[0]/X.shape[0]: .2f}')
print(f'Percentage of Val Set {X_val.shape[0]/X.shape[0]: .2f}')
print(f'Percentage of Set Set {X_test.shape[0]/X.shape[0]: .2f}')
# Out:
# Percentage of Train Set  0.80
# Percentage of Val Set  0.10
# Percentage of Set Set  0.10

# %% [markdown]
# ### Data Preprocessing

# %%
# convert labels to array
y_train = y_train.values
y_val = y_val.values
y_test = y_test.values

# %%
# feature scaling for numerical columns
scaler =  MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train[numerical_columns])
X_val_scaled = scaler.fit_transform(X_val[numerical_columns])
X_test_scaled = scaler.fit_transform(X_test[numerical_columns])

# %%
# feature encoding for categorical columns
encoder =  OneHotEncoder(sparse_output=False)
X_train_encoded = encoder.fit_transform(X_train[categorical_columns])
X_val_encoded = encoder.fit_transform(X_val[categorical_columns])
X_test_encoded = encoder.fit_transform(X_test[categorical_columns])

# %%
# combine numerical and categorical features
X_train_combined = np.hstack((X_train_scaled, X_train_encoded))
X_val_combined = np.hstack((X_val_scaled, X_val_encoded))
X_test_combined = np.hstack((X_test_scaled, X_test_encoded))

# %%
# random oversampler
ros = RandomOverSampler(random_state=0)
X_oversampled, y_oversampled = ros.fit_resample(X_train_combined, y_train)

# random undersampler
rus = RandomUnderSampler(random_state=0)
X_undersampled, y_undersampled = rus.fit_resample(X_train_combined, y_train)

# oversampling by SMOTE
smote = SMOTE(random_state=0)
X_smote, y_smote = smote.fit_resample(X_train_combined, y_train)

# %% [markdown]
# ### Model Training and Testing

# %%
# model architecture
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_smote.shape[1],)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # Use 1 unit for binary classification
])

# Define metrics
accuracy = 'accuracy'
precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
auc = tf.keras.metrics.AUC()
f1score = tfa.metrics.F1Score(num_classes=1, threshold=0.5)

# Compile the model with Binary Cross-Entropy Loss
model.compile(optimizer='adam', loss='binary_crossentropy', metrics = accuracy)

# Fit the model
model.fit(X_smote, y_smote, epochs=10, batch_size=30, validation_data=(X_val_combined, y_val))
# Out:
# Epoch 1/10
# 275/275 [==============================] - 1s 1ms/step - loss: 0.4807 - accuracy: 0.7668 - val_loss: 0.5478 - val_accuracy: 0.7147
# Epoch 2/10
# 275/275 [==============================] - 0s 1ms/step - loss: 0.4498 - accuracy: 0.7866 - val_loss: 0.4568 - val_accuracy: 0.7789
# Epoch 3/10
# 275/275 [==============================] - 0s 980us/step - loss: 0.4342 - accuracy: 0.7976 - val_loss: 0.5389 - val_accuracy: 0.7461
# Epoch 4/10
# 275/275 [==============================] - 0s 899us/step - loss: 0.4218 - accuracy: 0.8016 - val_loss: 0.5003 - val_accuracy: 0.7389
# Epoch 5/10
# 275/275 [==============================] - 0s 875us/step - loss: 0.4088 - accuracy: 0.8089 - val_loss: 0.4728 - val_accuracy: 0.7760
# Epoch 6/10
# 275/275 [==============================] - 0s 848us/step - loss: 0.3992 - accuracy: 0.8170 - val_loss: 0.4680 - val_accuracy: 0.7646
# Epoch 7/10
# ...

# %%
# evaluate on Test Set
test_loss, test_score = model.evaluate(X_test_combined,  y_test)

# Print the test loss and accuracy
print(f'Test Loss: {test_loss: .3f}')
print(f'Test Accuracy:{test_score: .3f}')
# Out:
# 22/22 [==============================] - 0s 845us/step - loss: 0.5967 - accuracy: 0.7407
# Test Loss:  0.597
# Test Accuracy: 0.741

# %% [markdown]
# ### Model Save

# %%
# save preprocessing steps
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(encoder, 'encoder.pkl')

# save model
joblib.dump(model, 'model.pkl')

print('Model Saved Sucessfully!')
# Out:
# Model Saved Sucessfully!
